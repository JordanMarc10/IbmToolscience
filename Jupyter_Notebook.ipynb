# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %%
My name is  **JordanJerome**.
<strong> "Data Science" </strong>

# %% [markdown]
# _I am interested in data science because its not only helping businesses make better decisions but is also helping them to find new opportunities. Data Science is also helping businesses to know their customers more closely_.

# %% [markdown]
# <h3>The following code displays transactions.csv </h3>

# %% [markdown]
# with open('transactions.csv', mode='w', newline='') as csv_file:
#   csv_writer = csv.writer(csv_file)
#   for row in transactions_data:
#     csv_writer.writerow(row)

# %%
* ONE
* TWO
* three
* four
